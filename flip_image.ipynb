# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

file = 'images/center_2019_01_15_23_03_54_135.jpg'
image = cv2.cvtColor(cv2.imread(file), cv2.COLOR_BGR2RGB)
flipped_image = cv2.flip(image,1)

plt.imshow(image)
plt.show()
plt.imshow(flipped_image)
plt.show()
